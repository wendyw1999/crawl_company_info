# %%
# 所有的需要import的package
# 需要提前安装chrome driver，安装方式参考 https://blog.csdn.net/wendyw1999/article/details/107414953
# 所有需要提前下载的依赖package都在requirements里面
# 批量安装：在cmd/terminal当前目录下输入: pip install -i requirements.txt
from __future__ import unicode_literals

import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import re
import requests
import os, os.path
from whoosh import index
from whoosh.qparser import QueryParser

import os, os.path
from whoosh import index
from jieba.analyse import ChineseAnalyzer

import pdfplumber
import whoosh.index as index

# ix = index.open_dir("indexdir")
from whoosh.query import And,Term,Or


from whoosh.fields import Schema, STORED, ID, KEYWORD, TEXT
import urllib

# %%
# webdriver 
def initialize():
    '''
    初始化一个Selenium chrome driver
    '''
    options = Options()
    options.add_argument("--headless")  # 无界面
    driver = webdriver.Chrome(options=options)   
    return driver

# 找到pdf所在的页面（html）
def find_report_links(id_list):   
    
    root_url = "http://data.eastmoney.com/notices/stock/"
    driver = initialize()
    print("Initializing Chrome Driver...")
    report_list = {}
    for i in id_list:
        print("Working on:  "+str(i))
        raw_url = root_url+str(i)+".html"
        
        try:
            driver.get(raw_url)
            report_link = click_next_page(driver)
            report_list[i]=report_link
            
        except:
            print('did not find the page on site')
    print("Closing Chrome Driver") 
    driver.quit()
    return report_list
#虚拟点击下一页
def click_next_page(driver):
    '''
    翻页
    '''
    time.sleep(2)
    curr_page = 1
    #check find report
    
    while True:
        
        try:
            
            
            found = find_report(driver)
            if found != False:
                print("Found the element at page: "+str(curr_page))
                
                return found
            next_page = driver.find_element_by_link_text("下一页")
            
            if next_page.get_attribute("class") == "nolink":
                print("Reached The Last Page,没有找到社会责任报告")
                
                return False
            next_page.click()
            curr_page+=1
            
            
            
        except:
            print("Something went wrong")
            print(curr_page)
            
            return False
            
        
            
# 在公告页面 翻页找到社会报告关键词的帖子    
def find_report(driver):
    '''
    网络爬虫找到社会责任报告帖子url，本页没有就翻页
    '''
    titles = driver.find_elements_by_class_name("overflow")
    pattern = re.compile(r'社会责任')
    for title in titles:
        check_match = bool(pattern.search(title.text))
        if check_match == True:
            
            
            html_url = title.get_attribute("href")
            return getPdf(html_url)
    return False
# 从pdf页面下载pdf到本地pdfs文件夹，file name为公司股票代码
def getPdf(url):
    
    '''
    帖子url --> 可下载的pdf所在url
    '''
    print(url)
    if type(url)!=str:
        return False
    
    
    
    
    pattern = re.compile(r'detail/(.*)/')
    company_id = pattern.findall(url)[0]
                         
                         
    
    company_id = pattern.findall(url)[0]
    pattern = re.compile(company_id+r'/(.*).html')
    pdf_link = "https://pdf.dfcfw.com/pdf/"+"H2_"+pattern.findall(url)[0]+"_1.pdf"
    
    getFile(company_id,pdf_link)
    return url

def getFile(name,url):
    '''
    通过pdf文档所在的网页url下载到本地
    '''
    if not os.path.exists("pdfs"):
        os.mkdir(company_id)
    
    os.chdir(os.path.join(os.getcwd(), "pdfs"))
    
    u = urllib.request.urlopen(url)
    f = open(name+".pdf", 'wb')
    print("下载pdf文档 Downloading pdf file to path:  ./pdfs/"+name+'.pdf')

    block_sz = 8192
    while True:
        buffer = u.read(block_sz)
        if not buffer:
            break

        f.write(buffer)
    f.close()
    os.chdir("..")
    
    create_index(name)
    print("成功创建全文索引 Successfully created whoosh index")
    


def create_index(company_id):
    '''
    从pdf创建索引
    '''


    analyzer = ChineseAnalyzer()
    schema = Schema(page=ID(stored=True), path=ID(stored=True), content=TEXT(stored=True, analyzer=analyzer))

    if not os.path.exists(company_id):
        
        os.mkdir(company_id)
    
    
    idx = index.create_in(company_id, schema)
    print("正在创建全文索引 creating whoosh index for "+company_id)
    writer = idx.writer()
    import pdfplumber
    fp = "pdfs/"+company_id+".pdf"
    #if fp doesn't exist do something
    with pdfplumber.open(fp) as pdf:
        pages = pdf.pages
        for i in range(len(pages)):
            content = pages[i]
            writer.add_document(
                page=str(i),
                path="/"+str(i),
                content=content.extract_text()
            )

    writer.commit()
    return True
def main():
    company_id = pd.read_csv("company_id.csv")
    f = open('company_id.csv', 'r')
    b = f.read()
    f.close()
    id_list = b.split("\n")
    reports = find_report_links(id_list)
    
    return reports
if  __name__ == '__main__':
    main()
# Out:
# Initializing Chrome Driver...
# Working on:  300737
# 1
# 2
# http://data.eastmoney.com/notices/detail/300737/AN202004201378264598.html
# Downloading pdf file to path:  pdfs/300737.pdf
# creating whoosh index for 300737
# Successfully created whoosh index
# Found the element at page: 2
# Closing Chrome Driver
# {'300737': 'http://data.eastmoney.com/notices/detail/300737/AN202004201378264598.html'}

# %%
# 搜某公司煤的使用量
company_id = "000002"

idx = index.open_dir(company_id)
to_search = input("输入你要搜索的关键词，用空格隔开，比如：标准 煤 吨： ")
to_search_list = to_search.split(" ")
query_list = [Term("content",i) for i in to_search_list]
myquery = Or(query_list)

with idx.searcher() as searcher:  
    
    results = searcher.search(myquery)
    if len(results) == 0:
        print("没有找到你想检索的内容No hits found")
    else:
        
        page_number = int(results[0]["page"])
        results.fragmenter = highlight.ContextFragmenter(maxchars=200, surround=40, charlimit=32768)
        results.formatter = highlight.UppercaseFormatter()
        outputs = [hit.highlights("content") for hit in results]
        
        
        for i in range(len(outputs)):
            page_num = results[i]["page"]
            output = outputs[i]
            print("="*15 +"Page "+ page_num+"="*15)
            print(output)
        page_number=input("【必须回答】你想打开pdf的第几页查看原图？(ex. 44) 如果不需要请输入n:  ")
        if page_number != "n":
            
            fp = "pdfs/"+company_id+".pdf"
            my_pdf = pdfplumber.open(fp)
            pages = my_pdf.pages 
            page = pages[int(page_number)]
            a = "|".join(to_search_list)

            im = page.to_image(resolution=125)
            dic = page.extract_words()
            pattern = re.compile(r""+a)
            print(pattern)

            result = [i for i in dic if bool(pattern.search(i["text"]))]
            im.reset()
            #用方框 在图片中标注出 目标词
            im.draw_rects(result)
            display(im)
# Out:
# 输入你要搜索的关键词，用空格隔开，比如：标准 煤 吨： 标准 煤
# ===============Page 32===============
# 万科2019年建筑技术研究进展及成果   万科2019年参编国际、国家、行业等标准情况
# 技术研发名录 研发进展 标准级别 数量 内容
# ISO国际标准 1项 《色漆和清漆——内墙涂料涂层质量评定现场试验方法》
# 协助落地北京成寿寺泊寓项目...体系
# 缩减施工周期，提升泊寓健康环境品质，为客户营造安心、舒心的居住环境。
# 国家标准 1项 《智慧城市 建筑及居住区 第1部分：智慧社区建设规范》
#    CECS标准：《机构出租住房性能评价标准》
# 运用红外热成像技术研究外墙保温、外墙砖脱落风险，并通过风险识别制
#    CECS...为客户提供
#    CECS标准：团体标准《智慧公寓建设评价指南》
# 安全的社区环境。    CECS标准：《装配式保温装饰组合外墙应用技术规程》
#    CECS标准：《民用建筑室内用强电分电器系统应用技术标准》
#    团体标准《住宅全装修评价标准》T/CRECC02-2018
# 统一防水构造、明确细部节点做法，更新隐蔽工程验收，包括
# ===============Page 24===============
# Report
# 企业社会责任报告
# 截至2019年底，泊寓
# 升级落地服务标准化运营流程SOP，创造良好的租住体验
# 业务已布局全国城市
# 34
# 为标准化开展长租公寓客户服务工作，2019年，我们落地实施服务标准化运营流程SOP。
# 个
# 该流程从客户租住全流程体验的角度出发，结合“四心”服务主张，按照...前-体验中-
# 体验后”模块，结合目的、步骤、行为标准、话术及避免事项五个关键要素，完善长租公
# 累计开业房间超过
# 11
# 寓服务标准体系，为客户提供更加安心舒适的租住体验。
# 万间
# 开展“回归家的味道”家宴活动，来自五湖四海...板材、柜体、建筑及辅材用胶
# 均为无醛产品，装修全过程甲醛与TVOC
# 排放仅为国家标准限值20%，且满足国
# 长租公寓无醛健康体系从源头为公寓租户提供绿色租赁保障
# ===============Page 33===============
# 社会的必然选择。我们积极推进绿色建筑 绿色建筑覆盖率 2019年，满足绿色建筑标准的面积
# 100
# 以绿色人居引领绿色生活。 发展，在遵循《绿色建筑评价标准》等国家和行业标准的基础上， 4662.0万平方米，其中满足绿色
# %
# 编制并在集团范围...内推广使用《万科集团绿色建筑标准指引》， 一、二星标准的项目面积4254.2
# 严格把控建筑从设计到运营全生命周期的环保管理，在保证...面积比为
# 佛山 信通大厦 9.33 设计
# 系标准、建筑隔震与减振技术应用指引， 85.83%
# 为建筑行业绿色健康发展贡献有生
# ===============Page 44===============
# 74.20 538.04
# A2资源使用
# A2.1 能源总耗量c）,4） 吨标准煤 1680.38 392.62 2073.01
# 数据计算参考标准
# 能源消耗 能源消耗密度5） 吨标准煤╱平方米 0.008 0.007
# 1）汽油、柴油、天然气、管道煤气等产生的直接二氧...建筑节能
# 外购热力 吉焦 8383.84 1382.40 9766.24 设计标准》（JGJ26－2010）计算；
# A2.2 办公生活用水 吨 170839.47 100528.61...271368.08 4）能源总耗量参考中国标准《GB/T 2589-2008 综合能耗计算通则》进行
# 标准煤折算；
# 水资源消耗 办公生活用水密度5） 吨/平方米 0.81 1.75
# 5）温室气体
# ===============Page 1===============
# 57
# 响应落实精准扶贫、
# 联合国全球契约十项原则
# 乡村振兴战略
# 环境之道
# 国际标准化组织《ISO26000：社会责任指南（2010）》
#       07
# 59 79
# 全球...持续发展标准委员会《GRI可持续发展报告标准》（GRI Standards） 精准扶贫                                                      创新绿色技术     应对气候变化
# 17
# 63 81...标准《社会责任报告编制指南》（GB/T36001-2015） 乡村振兴                                                      推进绿色建造      保护生物多样性
# 67 85
# 中国社会科学研究院《中国企业社会责任报告编写指南
# ===============Page 26===============
# 加速布局冷链物流全国业务版图，致力于成 库123个，冷库15个。可租赁物业 打造标准办公及产业园两大产品线，构筑以企业为核心的基础服务与产业服务平台...生态系统。
#  万纬物流荣获“全国仓储地产十强企业”称号
# 万物商企
# 案例 高标准建设物流园，助力京东大件物流提效 我们从设计建造的前介顾问服务、物业管理...货柜，拥有完善的配套设施。凭借大面积、
# 高标准、区位优越等稀缺优势，万纬中山物流
# 案例 上线区块链电子发票，助力业主畅享智能物业
# ===============Page 56===============
# 种手段、5项
# 提升的五位一体化安全管理模型，综合施措实现安全防护实现100%标准化，大型设备管理实现100%可
# 视化，隐患排查覆盖率100%，安全教育覆盖率...现场安全。
# 1个目标 争创可在全国范围进行学习交流的建设工程、项目施工安全生产标准化工地
# 安全理念：生命至上，安全运营第一
# 2个基础
# 安全方针：安全第一，预防为主...安全监督体系
# 4种手段 安全管理信息化      安全防护标准化        安全管理人性化        安全管理可视化
# 两项清单                   组合式教育培训        班前
# ===============Page 20===============
# 对万科产品进行全方位管控，为好产品、好服务保驾护航。
# 空气 光
# 严格的空气质量标准，设置高 遵从自然日光节律，智能调节
# 案例 严控室内空气质量，交付低甲醛建筑
# 效的新风...住宅交付等环节涉及的甲醛、TVOC 等核心指标。在
# 原材料采购阶段，应用高于国家标准的要求对地板、柜体等关键材料中的有害物质（包括甲醛）含量进行
# 把控...提升用水体验 振降噪体系，打造静谧
# 无扰的健康声环境 材料类别 国标要求 万科标准
# 地板 甲醛释放限量≤0.124mg/m³ 甲醛释放限量≤0.050mg/m³
# 柜体 甲醛释放限量≤0.124
# ===============Page 28===============
# 客户关系“6+2 步法” 保证服务质量，各业态均制定有问题响应、处理、关闭、回访的标准客户服务操作指引，
# 应机制
# 快速有效解决客户问题，保障客户权益。
# 我们重视客户关系...安全管理规范》
# 2019年，我们持续迭代客户关系“6+2 步法”要求，并注重管控标准的执行情况，迭代后的步法评估标准
# 等制度规范，对物业服务、房屋销售等业务中收集的客户资料进行严格保密，针对在线...个大项、82条细则。同时确定了两个底线要求：展示区强控底线要求30条、交付底线标准8条。
# 家等在线服务系统进行客户数据脱敏、数据加密管理，常态化对员工开展客户信息安全
# ===============Page 8===============
# 健康管理和作物精准营养管理，服务3000亩果
# 园的测土配方施肥。
# 建立寿宁葡萄标准化栽培管理规程：项目专家组帮助修订并建设新版《寿宁葡萄标准化栽培管理规程（绿色
# A级）》，指导葡萄绿色生产上一个新台阶。新规程中导入集成农业
# 你想打开pdf的第几页？(ex. 44) 如果不需要请输入n:  n
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-72721344099f> in <module>
#      32             my_pdf = pdfplumber.open(fp)
#      33             pages = my_pdf.pages
# ---> 34             page = pages[int(page_number)]
#      35             a = "|".join(to_search_list)
#      36
#
# ValueError: invalid literal for int() with base 10: 'n'
